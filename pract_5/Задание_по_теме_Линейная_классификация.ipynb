# %% [markdown]
# # Задание "Исследование линейной классификации"
#
# Вам предстоит исследовать два метода классификации на двух датасетах и сравнить качество классификации.

# %%
# Здесь подключайте необходимые библиотеки

# %% [markdown]
# ### Создание первого набора данных
#
# [1] Используя make_classification из sklearn.datasets, сгенерируйте набор данных для бинарной классификации, содержащий 200 объектов. У каждого объекта сделайте 2 независимых вещественных признака. Добавьте 5% шума в сгенерированные данные.

# %%
# ваш код здесь

# %% [markdown]
# [2] Выведите первые 10 объектов сгенерированного набора данных и метки классов для них.

# %%
# ваш код здесь

# %% [markdown]
# [3] Постройте диаграмму рассеяния для отображения созданного набора данных. Точки разных классов рисуйте разными цветами. Диаграмму, оси и легенду подпишите.

# %%
# ваш код здесь

# %% [markdown]
# [4] Разделите набор данных на на обучающую и тестовую выборку. Размер тестовой выборки сделайте 10%

# %%
# ваш код здесь

# %% [markdown]
# [5] Выведите размеры полученной тестовой и обучающей выборки, а также по 10 последних элементов в каждой из них с указанием классов.

# %%
# ваш код здесь

# %% [markdown]
# ### Использование методов линейной классификации
#
# [6] Обучите модель Логистической регрессии на обучающей выборке

# %%
# ваш код здесь

# %% [markdown]
# ЗДЕСЬ ВСТАВЬТЕ КРАТКОЕ ОПИСАНИЕ МОДЕЛИ ЛОГИСТИЧЕСКОЙ РЕГРЕССИИ

# %% [markdown]
# [7] Выполните предсказания классов для обучающей и тестовой выборки, используя модель, обученную на предыдущем шаге.

# %%
# ваш код здесь

# %% [markdown]
# [8] Оцените качество предсказаний для обучающей и тестовой выборки, используя метрику `accuracy`.

# %%
# ваш код здесь

# %% [markdown]
# [9] Обучите модель Ридж-классификатора на обучающей выборке

# %%
# ваш код здесь

# %% [markdown]
# ЗДЕСЬ ВСТАВЬТЕ КРАТКОЕ ОПИСАНИЕ МОДЕЛИ РИДЖ-РЕГРЕССИИ

# %% [markdown]
# [10] Выполните предсказания классов для обучающей и тестовой выборки, используя модель, обученную на предыдущем шаге.

# %%
# ваш код здесь

# %% [markdown]
# [11] Оцените качество предсказаний для обучающей и тестовой выборки, используя метрику `accuracy`.

# %%
# ваш код здесь

# %% [markdown]
# ### Второй набор данных
#
# [12] Выберите набор данных, который можно использовать для бинарной классификации. Можно использовать "игрушечные" наборы данных из sklearn.datasets. Можно взять данные с kaggle.com. Если в изначальном датасете классов больше двух, можно отфильтровать данные, оставив только два класса. Загрузите данные из выбранного набора. Выведите первые несколько записей и метки классов к ним. Постройте диаграмму рассеяния для этого набора данных, взяв только два признака (наиболее важных на Ваш взгляд).

# %%
# ваш код здесь

# %% [markdown]
# [13] Выполните задания с 4 по 11 для второго набора данных. При обучении используйте все признаки исходного набора данных.

# %%
# ваш код здесь

# %% [markdown]
# [14] Выполните задания с 4 по 11 для второго набора данных. При обучении используйте только некоторые признаки исходного набора данных. Какие именно признаки дадут лучший результат попробуйте определить самостоятельно, используя графики pairplot(). Поэкспериментируйте, выбирая разные подмножества признаков для анализа.

# %%
# ваш код здесь

# %% [markdown]
# [15] Сформулируйте общий вывод по результатам всей работы.

# %% [markdown]
# ВЫВОД: ЗАПИШИТЕ ВЫВОД ПО РЕЗУЛЬТАТАМ ВСЕЙ РАБОТЫ
