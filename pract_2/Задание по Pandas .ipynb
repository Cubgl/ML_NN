# %% [markdown]
# ### Практическое задание по Pandas

# %%
import pandas as pd

# %% [markdown]
# Задание 1. Скачать файл FIFA.csv и загрузить датасет.

# %%
# ваш код здесь

# %% [markdown]
# Задание 2. Выведите первые 5 строк загруженного набора данных

# %%
# ваш код здесь

# %% [markdown]
# Задание 3. Определите, есть ли пропущенные данные в наборе. Если есть, то заполните пропущенные ячейки нулями

# %%
# ваш код здесь

# %% [markdown]
# Задание 4. Установите максимальное количество строк, отображаемых при выводе датасете равным 20.
#
# Используйте функцию pd.set_option(), параметр 'display.max_rows'.

# %%
# ваш код здесь

# %% [markdown]
# Задание 5. Сгруппируйте строки датасета по году и подсчитайте количество матчей на каждом чемпионате мира.

# %%
# ваш код здесь

# %% [markdown]
# Задание 6. Выведите для чемпионата мира, состоявшегося в 2014 году, даты матчей и город проведения

# %%
# ваш код здесь

# %% [markdown]
# Задание 7. Добавить в таблицу столбец goals, в который записать общее количество голов, забитых в каждом матче (Home.Team.Goals  + Away.Team.Goals ) и вывести на экран дату проведения матча, названия команд-участников и общее количество забитых голов.

# %%
# ваш код здесь

# %% [markdown]
# Задание 8. Посчитать общее количество голов, забитых на каждом чемпионате мира, а также минимальное и максимальное количество голов за один матч (использовать метод agg).

# %%
# ваш код здесь

# %% [markdown]
# Задание 9. Сгруппировать данные по городу и стадиону и вывести информацию по количеству матчей, проведенных на каждом стадионе.

# %%
# ваш код здесь

# %% [markdown]
# Задание 10. Посчитать среднее количество голов, забитых в одном матче на каждом Чемпионате мира.

# %%
# ваш код здесь

# %% [markdown]
# Задание 11. Вывести информацию о тех годах, где суммарное количество забитых мячей было больше 150 (вывести год и количество голов)

# %%
# ваш код здесь

# %% [markdown]
# Задание 12. Для страны введенной пользователем определите, сколько игр она провела за все чемпионаты мира

# %%
# ваш код здесь

# %% [markdown]
# Задание 13. Постройте датасет, в котором для каждого города проведения укажите количество игр.

# %%
# ваш код здесь

# %% [markdown]
# Задание 14. Для набора данных, полученного в задании 13, переименуйте столбец с количеством проведенных игр, установив ему имя Match_count. Используйте метод rename.

# %%
# ваш код здесь

# %% [markdown]
# Задание 15. Набор данных, полученный в задании 14, упорядочьте по столбцу Match_count по убыванию.

# %%
# ваш код здесь

# %% [markdown]
# Задание 16. На основе набора данных, полученного в задании 15, сформируйте новый набор данных, в котором оставьте только 20 первых записей исходного набора.

# %%
# ваш код здесь

# %% [markdown]
# Задание 17. По набору данных, полученному в задании 16, постройте столбиковую диаграмму. На диаграмме должен быть заголовок и подписи осей, легенду не выводите.

# %%
# ваш код здесь

# %% [markdown]
# Задание 18. Постройте набор данных, в котором для каждого года проведения выведите общее количество голов всех игр, а также количество голов на домашнем поле и поле противника.

# %%
# ваш код здесь

# %% [markdown]
# Задание 19. По набору данных, полученному в задании 18, постройте горизонтальную столбиковую диаграмму (kind='barh'). На диаграмме должен быть заголовок, подписи осей и легенда.

# %%
# ваш код здесь

# %% [markdown]
# Задание 20. Придумайте свою визуализацию данных исходного набора и реализуйте ее.

# %%
# ваш код здесь
