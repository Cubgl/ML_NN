# %% [markdown]
# # Практическое задание "Линейные и нелинейные модели в машинном обучении"

# %% [markdown]
# ## Задача о спросе на прокат велосипедов

# %% [markdown]
# Загрузим данные по спросу на прокат велосипедов (целевой столбец cnt - количество) в зависимости от наличия праздника/выходного, времени года, месяца, дня недели, погоды (влажность, скорость ветра, температура, средняя температура) и других факторов. Будем предсказывать спрос на количество велосипедов, которые запросят в прокат.
#
# **А именно, для каждого дня проката известны следующие признаки:**
#
# - season: 1 - весна, 2 - лето, 3 - осень, 4 - зима
# - yr: 0 - 2011, 1 - 2012
# - mnth: от 1 до 12 (соответственно январь...декабрь)
# - holiday: 0 - нет праздника, 1 - есть праздник
# - weekday: от 0 до 6 (соответственно понедельник...воскресенье)
# - workingday: 0 - нерабочий день, 1 - рабочий день
# - weathersit: оценка благоприятности погоды от 1 (чистый, ясный день) до 4 (ливень, туман)
# - temp: температура по шкале Цельсия
# - atemp: средняя температура  по шкале Цельсия
# - hum: влажность
# - windspeed(mph): скорость ветра в милях в час
# - windspeed(ms): скорость ветра в метрах в секунду
# - cnt: количество арендованных велосипедов (это целевой признак, его мы будем предсказывать).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# [1] Загрузите датасет с данными проката велосипедов из файла `bikes_rent.csv` и выведите первые несколько строк загруженного набора данных

# %%
# ваш код здесь

# %%
# ваш код здесь

# %% [markdown]
# [2] Выведите названия столбцов загруженного датасета

# %%
# ваш код здесь

# %% [markdown]
# [3] С помощью метода `<DataFrame>.describe()` выведите описательные статистики набора данных.

# %%
# ваш код здесь

# %% [markdown]
# #### Борьба с мультколлинеарностью. Отбор признаков.

# %% [markdown]
# Иногда в данных мы можем наблюдать так называемую коллинеарность (мультиколлинеарность) — когда два или несколько признаков сильно скоррелированы, в матрице  𝐗  это проявляется в виде "почти" линейной зависимости столбцов.
#
#
# Силу взаимосвязи двух количественных признаков можно определить при помощи коэффициента Пирсона – это математический коэффициент корреляции, представляющий взаимосвязь между двумя переменными, обозначаемыми как X и Y.
# Коэффициенты Пирсона варьируются от +1 до -1, где +1 представляет положительную корреляцию, -1 представляет отрицательную корреляцию, а 0 означает отсутствие взаимосвязи.  Если две переменные связаны между собой, так что значение коэффициента корреляции достаточно большое, то в этом случае можно прогнозировать (с некоторой точностью) неизвестное значение одной переменной по известному значению другой. Считают явление коллинеарности в исходных данных установленным, если коэффициент парной корреляции между двумя переменными больше 0,7. Чтобы избавиться от коллинеарности, из модели исключают один из линейно связанных между собой факторов. Предпочтение при этом отдается не фактору, более тесно связанному с результатом, а фактору, который при достаточно тесной связи с результатом имеет наименьшую тесноту связи с другими факторами.
#
# С целью выявления факта коллинеарности факторов составляется матрица парных коэффициентов корреляции, измеряющих тесноту связи каждого из факторов-признаков с результативным фактором и между собой.
#
#
# В случае если есть мультиколлинеарность, чтобы модель получилась адекватной, можно
#
# * делать отбор признаков (нужно удалять нецелевые признаки, которые линейно зависят от других или имеют высокую корреляцию с другими признаками),
# * применять линейную регрессию с L1-, L2- регуляризацией.

# %%
# ваш код здесь

# %% [markdown]
# ##### **Посмотрим на корреляционную матрицу:** (чем ближе коэффициенты к 1, тем большая зависимость наблюдается у признаков, если коэффициент положительный, то зависимость прямая (положительное направление), иначе обратная (отрицательное направление) )

# %% [markdown]
# [4] С помощью метода `<DataFrame>.corr()` выведите корреляционную матрицу

# %%
# ваш код здесь

# %% [markdown]
# [5] С помощью фукнции `heatmap` библиотеки `Seaborn` выведите тепловую карту по матрице корреляции. В каждой клеточке тепловой карты пишите значение корреляции с точностью 2 знака после запятой.

# %%
# ваш код здесь

# %% [markdown]
# [6] Найдите признаки, имеющие сильную корреляцию друг с другом (|коэффициент корреляции| >= 0.75). Удалите из каждой пары признаков сильно коррелирующих друг с другом один из них. Постройте тепловую карту по модифицированному набору признаков и прокрнтроллируйте, что не осталось признаков, имеющих сильную корреляции друг с другом.

# %%
# ваш код здесь

# %% [markdown]
# #### Рассмотрим всевозможные графики для лучшего понимания набора:

# %% [markdown]
# [7] С помощью функции `histplot` библиотеки `Seaborn` постройте гистограмму распределения значенй целевого признака `cnt` - количество выданных в прокат велоспипедов. Дианпамму и оси подпишите. Установив параметр `kde` равным `True` добавьте на график плавную кривую плотности ядра распределения.

# %%
# ваш код здесь

# %% [markdown]
# [8] Постройте график изменения целевого признака во времени

# %%
# ваш код здесь

# %% [markdown]
# [9] С помощью функции `violinplot` библиотеки `Seaborn` постройте "скрипичную диаграмму". По оси Х откладывайте признак `season` или `mnth`, по оси Y значения целевого признака. "Скрипичная диаграмма» играет аналогичную роль, что и диаграмма «ящик с усами». Она показывает распределение точек данных после группировки по одной (или нескольким) переменным. В отличие от диаграммы «ящик с усами», каждая скрипка строится с использованием оценки плотности ядра базового распределения.

# %%
# ваш код здесь

# %% [markdown]
# [10] Выберите пару признаков, наиболее сильно коррелирующих со значениями целевого признака, и постройте две scatter-диаграммы, откладывая по оси Х один из выбранных признаков, а по оси Y значения целевого признака.

# %%
# ваш код здесь

# %% [markdown]
# # Линейная регрессия

# %%
# здесь подключайте необходимые для выполненния данного раздела библиотеки и функции

# %% [markdown]
# [11] Разделите данных на признаковое описание объектов (X) и значения целевого признака (y). В качестве признакового описания объектов выберите один признак, наиболее сильно коррелирующий со значением целевой функции.

# %%
# ваш код здесь

# %% [markdown]
# [12] Разделите X и y на обучающую и тестовую выборку

# %%
# ваш код здесь

# %% [markdown]
# [13] Обучите модель линейной регрессии `LinearRegression` из библиотеки `sklearn`. Выведите аналитический вид функции, подобранной моделью.

# %%
# ваш код здесь

# %% [markdown]
# [14] Нарисуйте диаграмму рассеяния, откладывая по оси X признак, взятый в обучение, а по оси Y целевой признак. Поверх этой диаграммы рассеяния нарисуйте прямую линию, которую выбрала обученная модель.

# %%
# ваш код здесь

# %% [markdown]
# [15] Выберите случайным образом один объект из тестовой выборки и сделайте предсказание для него. Сравните полученное предсказание с истинным ответом. На сколько мы ошиблись?

# %%
# ваш код здесь

# %% [markdown]
# [16] Посчитайте среднюю квадратичную и среднюю абсолютную ошибку на тестовой выборке для построенной модели

# %%
# ваш код здесь

# %% [markdown]
# [17] Выполните задания с 13 до 16 для модели линейной регрессии с L1-регуляризацией. Сравните полученные результаты.

# %%
# ваш код здесь

# %% [markdown]
# [18] Возьмите в обучение линейных моделей все признаки датасета, оставшиеся после выполнения п.6, и выполните задания с 11 по 17 (диаграмму рассеяния и график найденной линейной зависимости не стройте). Сравните результаты с полученными ранее.

# %%
# ваш код здесь

# %% [markdown]
# [19] Выведите коэффициенты для модели Lasso, полученной в предыдущем задании, и оцените с их помощью важность признаков

# %%
# ваш код здесь

# %% [markdown]
# # Случайный лес

# %% [markdown]
# [20] Постройте модель случайного леса (задания 11-13, 15-17) сначала для всех признаков датасета, потом только для тех признаков, которые выявили как наиболее важные в задании 19. Сравните полученные результаты.

# %%
# ваш код здесь

# %% [markdown]
# [21] Оцените важность признаков, используя модель случайного леса, выберите наиболее важные. Сравните полученный результат с результатом задания 19. Если выявленное множество наиболее важных признаков отличается от множества, полученого при выполнении задания 19, обучите модель случайного леса, используя только эти признаки (задания 11-13, 15-17).

# %%
# ваш код здесь

# %% [markdown]
# [22] Запишите вывод для всей работы. Выберите наиболее удачную на Ваш взгля модель.

# %% [markdown]
# ##### ВАШ ВЫВОД ЗДЕСЬ
