# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **Задание по теме "Визаулизация в Matplotlib"**

# %% [markdown]
# ### <a name="ex2"></a> Упражнение 1, Первый график
# Постройте график $y=(x+2)(x-1)(x-2)$ для $x$ от $-3$ до $+3$, используя пунктирную красную линию. На том же рисунке постройте синий круг для каждой точки, где $y$ равен нулю. Установите размер маркеров равным 10 (вам может потребоваться ознакомиться со справкой `plt.plot`, чтобы узнать, как это сделать). Обозначьте оси как «ось X» и «ось Y». Добавьте заголовок «Мой первый график».

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %%
# ваш код здесь

# %% [markdown]
# ### <a name="ex3"></a> Упражнение 2. Загрузка данных и добавление легенды
#
# Вам предоставлены файлы данных, содержащие среднемесячную температуру в Голландии, Нью-Йорке и Пекине. Данные по Нидерландам хранятся в файле holland_temperature.dat, а остальные имена файлов аналогичны.
#
# Числовые данные можно загрузить из текстового файла, используя функцию `loadtxt` библиотеки `numpy` (`np.loadtxt`). В каяетве переметра в эту функицю нужно передать полное имя файла (путь в имени файла можно не указывать, если файл находится в текущем каталоге). Например, данные среднемесяной температоры в Бельгии можно загрузить командой:
#
# `beijing = np.loadtxt('beijing_temperature.dat')`
#
#  Постройте график зависимости температуры для каждого местоположения от номера месяца (начиная с 1 для января) на одном графике.
#
# Добавьте легенду, используя функцию `plt.legend(['line1','line2'])` и т. д., но с более описательными именами. Узнайте больше о команде legend, использующей plt.legend?.
#
# Разместите легенду в подходящем месте (можно использовать верхний левый угол или позволить Python выбрать лучшее место).

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %%
# ваш код здесь

# %% [markdown]
# ### <a name="ex4"></a> Упражнение 3. Подграфики и фигурные маркеры-галочки
# Загрузите среднемесячную температуру воздуха и морской воды для Голландии. Создайте один график с двумя графиками, расположенными друг над другом, с помощью команды subplot (используйте команду plt.subplot?, чтобы узнать, как это сделать). На верхнем графике отобразите температуру воздуха и морской воды.
#
# Обозначьте деления на горизонтальной оси как «янв», «фев», «мар» и т.д., а не числа. Используйте команду plt.xticks?, чтобы узнать, как это сделать. На нижнем графике отобразите разницу между температурой воздуха и морской воды.
#
# Добавьте легенды, подписи осей и всё остальное.

# %% [markdown]
# ![3.PNG](data:image/png;base64,...)

# %%
# ваш код здесь

# %% [markdown]
# ### <a name="ex5"></a> Упражнение 4. Круговая диаграмма
# На Олимпийских играх 2012 года в Лондоне десять стран (плюс все остальные), получивших золотые медали, были следующими: ['USA', 'CHN', 'GBR', 'RUS', 'KOR', 'GER', 'FRA', 'ITA', 'HUN', 'AUS', 'OTHER']. Они получили [46, 38, 29, 24, 13, 11, 11, 8, 8, 7, 107] золотых медалей соответственно.
#
# Постройте круговую диаграмму (используйте plt.pie? или перейдите к галерее круговых диаграмм в matplotlib) для 10 лучших
# обладателей золотых медалей и остальных участников Олимпийских игр в Лондоне. Попробуйте использовать ключевые аргументы, чтобы график выглядел красиво.
#
# Вы можете использовать команду plt.axis('equal'), чтобы уравнять шкалы по горизонтальной и вертикальной осям, и тогда круговая диаграмма будет выглядеть как круг, а не как эллипс. Используйте ключевое слово colors в круговой диаграмме, чтобы задать последовательность цветов.
#
# Последовательность должна быть заключена в квадратные скобки, каждый цвет должен быть заключен в кавычки с сохранением регистра, и они должны быть разделены запятыми, например, ['MediumBlue','SpringGreen','BlueViolet']; последовательность повторяется, если её недостаточно.

# %% [markdown]
# ![4.PNG](data:image/png;base64,...)

# %%
# ваш код здесь

# %% [markdown]
# Отобразите процентное соотношение долей на круговой диаграмме. Увеличьте размер диаграммы и измените цвет заголовка.

# %% [markdown]
# ![5.PNG](data:image/png;base64,...)

# %%
# ваш код здесь

# %% [markdown]
# # Творческое задание
#
# Постройте три любых диаграммы по любым своим данным (можно взять из Интернета, курсовой, лаборатороной работы и т.п.)
#
# Диаграммы должны быть разных типов из числа тех, которые не использовались ранее в данном задании (стобчатая, гистограмма, тепловая карта, диаграмма рассеяния и т.д.).
#
# Как минимум две диаграммы посторойте с использованием библиотеки `seaborn`.
#
# Ниже каждой диаграммы разместите текстовое поле, в котором опишите словами смсысл постренной визуализации.

# %%
# ваш код здесь
